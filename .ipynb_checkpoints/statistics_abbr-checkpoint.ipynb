# %%
import pandas as pd
import json

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

large = 22; med = 14; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (12, 7),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)

# %%
with open('all_idioms.json', 'r', encoding='UTF-8') as f:
    data = tuple(json.load(f))

abbrs = {'презрит', 'эвф', 'груб', 'шутл-ирон', 'инф', 'ит', 'вульг', 'грубо-прост', 'канц', 'фр', 'мор', 'бран', 'поэт', 'устар', 'неодобрит', 'высок', 'одобр', 'шутл-фамильярн', 'этногр', 'ритор', 'книжн', 'восторж', 'этикет ф', 'посл', 'прост', 'библ', 'жарг', 'обл', 'шахм', 'офиц', 'миф', 'погов', 'юр', 'лит', 'доревол', 'перен', 'нов', 'фольк', 'спец', 'предосуд', 'еванг', 'лат', 'публиц', 'торж', 'греч', 'греч миф', 'спорт', 'англ', 'араб', 'ист', 'воен', 'др-греч', 'уничиж', 'пренебр', 'нем', 'пориц', 'разг', 'фам', 'экспрес', 'физ', 'театр', 'народно-поэт', 'церк-слав', 'охот', 'детск', 'иpoн', 'церк', 'шутл', 'филос', 'рел'}
len(abbrs)
# Out:
# 70

# %%
abbrs = sorted(list(abbrs))

# %%
# %%script false
# df = pd.DataFrame(columns=['phrase', 'meaning', 'dictionary'] + sorted(list(abbrs)))
# for phrase_dict in data:
#     semantics_set = phrase_dict['semantics']
#     for meaning_dict in semantics_set:
#         if 'abbr' in list(meaning_dict.keys()) and 'dictionary' in list(meaning_dict.keys()):
#             df.loc[len(df)] = [phrase_dict['phrase'],
#                                meaning_dict['meaning'],
#                                meaning_dict['dictionary']] + [True if abbr in meaning_dict['abbr'] else False for abbr in abbrs]

# %%
df.head(10)
# Out:
#                                        phrase  \
# 0            [а вот на тебе!, и вот на тебе!]
# 1                         [а был ли мальчик?]
# 2                                     [а вот]
# 3                    [а вот и нет, вот и нет]
# 4  [а ларчик просто открывался (открывается)]
# 5                            [а не то, не то]
# 6                            [а не то, не то]
# 7                    [а поди ж ты, поди ж ты]
# 8                               [а то бы вот]
# 9                               [а то как же]
#
#                                              meaning dictionary   англ   араб  \
# 0         Выражение удивления, разочарования и т. п.    Fedorov  False  False
# 1  Было ли что-либо в действительности, на самом ...    Fedorov  False  False
# 2                                Напротив, наоборот.    Fedorov  False  False
# 3  Не выходит, нельзя сделать то, что намечается,...    Fedorov  False  False
# 4          Дело ясно, не требует долгих размышлений.    Fedorov  False  False
# 5                         Иначе, в противном случае.    Fedorov  False  False
# 6                                      Либо, или же.    Fedorov  False  False
# 7  Выражение изумления, восхищения, недоумения и ...    Fedorov  False  False
# 8  Могло произойти, случиться что-либо непредвиде...    Fedorov  False  False
# 9               Да, конечно, непременно, разумеется.    Fedorov  False  False
#
#     библ   бран   воен восторж  вульг  ... церк-слав   шахм   шутл шутл-ирон  \
# 0  False  False  False   False  False  ...     False  False  False     False
# 1  False  False  False   False  False  ...     False  False  False     False
# 2  False  False  False   False  False  ...     False  False  False     False
# 3  False  False  False   False  False  ...     False  False  False     False
# 4  False  False  False   False  False  ...     False  False  False     False
# 5  False  False  False   False  False  ...     False  False  False     False
# 6  False  False  False   False  False  ...     False  False  False     False
# 7  False  False  False   False  False  ...     False  False  False     False
# 8  False  False  False   False  False  ...     False  False  False     False
# 9  False  False  False   False  False  ...     False  False  False     False
#
#   шутл-фамильярн    эвф экспрес этикет ф этногр     юр
# 0          False  False    True    False  False  False
# 1          False  False    True    False  False  False
# 2          False  False   False    False  False  False
# 3          False  False    True    False  False  False
# 4          False  False   False    False  False  False
# 5          False  False   False    False  False  False
# 6          False  False   False    False  False  False
# 7          False  False    True    False  False  False
# 8          False  False   False    False  False  False
# 9          False  False    True    False  False  False
#
# [10 rows x 73 columns]

# %%
# распределение фраз по количеству помет
#create a column with a tuple of all idiom's labels
row_labels = []
label_combinations = []
for ind, row in df.loc[:, 'англ': 'юр'].iterrows():
    row_labels.append(len(row[row].index))
    label_combinations.append(tuple(row[row].index))

df['label_counts'] = row_labels
df['label_combinations'] = label_combinations

# %%
df.head(-20)
# Out:
#                                              phrase  \
# 0              ['а вот на тебе!', 'и вот на тебе!']
# 1                             ['а был ли мальчик?']
# 2                                         ['а вот']
# 3                      ['а вот и нет', 'вот и нет']
# 4      ['а ларчик просто открывался (открывается)']
# ...                                             ...
# 31952                                  ['На языке']
# 31953                                  ['На языке']
# 31954                                ['Общий язык']
# 31955                           ['Придержать язык']
# 31956                           ['Проглотить язык']
#
#                                                  meaning dictionary   англ  \
# 0             Выражение удивления, разочарования и т. п.    Fedorov  False
# 1      Было ли что-либо в действительности, на самом ...    Fedorov  False
# 2                                    Напротив, наоборот.    Fedorov  False
# 3      Не выходит, нельзя сделать то, что намечается,...    Fedorov  False
# 4              Дело ясно, не требует долгих размышлений.    Fedorov  False
# ...                                                  ...        ...    ...
# 31952  употребляется при обозначении сильного желания...    Volkova  False
# 31953                                 в речи, разговоре.    Volkova  False
# 31954           взаимное понимание между кем-, чем-либо.    Volkova  False
# 31955     удержаться от того, чтобы говорить, помолчать.    Volkova  False
# 31956  о молчащем человеке, который не может или не х...    Volkova  False
#
#         араб   библ   бран   воен  восторж  вульг  ...   шутл  шутл-ирон  \
# 0      False  False  False  False    False  False  ...  False      False
# 1      False  False  False  False    False  False  ...  False      False
# 2      False  False  False  False    False  False  ...  False      False
# 3      False  False  False  False    False  False  ...  False      False
# 4      False  False  False  False    False  False  ...  False      False
# ...      ...    ...    ...    ...      ...    ...  ...    ...        ...
# 31952  False  False  False  False    False  False  ...  False      False
# 31953  False  False  False  False    False  False  ...  False      False
# 31954  False  False  False  False    False  False  ...  False      False
# 31955  False  False  False  False    False  False  ...  False      False
# 31956  False  False  False  False    False  False  ...  False      False
#
#        шутл-фамильярн    эвф  экспрес  этикет ф  этногр     юр  label_counts  \
# 0               False  False     True     False   False  False             2
# 1               False  False     True     False   False  False             2
# 2               False  False    False     False   False  False             1
# 3               False  False     True     False   False  False             2
# 4               False  False    False     False   False  False             1
# ...               ...    ...      ...       ...     ...    ...           ...
# 31952           False  False    False     False   False  False             0
# 31953           False  False    False     False   False  False             0
# 31954           False  False    False     False   False  False             0
# 31955           False  False    False     False   False  False             1
# 31956           False  False    False     False   False  False             0
#
#         label_combinations
# 0      ('разг', 'экспрес')
# 1      ('разг', 'экспрес')
# 2                ('разг',)
# 3      ('разг', 'экспрес')
# 4                ('иpoн',)
# ...                    ...
# 31952                   ()
# 31953                   ()
# 31954                   ()
# 31955            ('разг',)
# 31956                   ()
#
# [31957 rows x 75 columns]

# %%
# %%script false
# df.to_csv('dataframe.csv', sep=',', encoding='utf-8')

# %%
df_default = pd.read_csv('dataframe.csv', sep=',')

# %%
del df_default['Unnamed: 0']

# %%
phrases = df['phrase'].tolist()
phrase_one = set([phrase  for phrase in phrases if phrases.count(phrase) == 1])
df = df_default[df_default['phrase'].isin(phrase_one)]

# %%
description = df.describe()
description
# Out:
#        label_counts
# count  19409.000000
# mean       0.949147
# std        0.830702
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19409 entries, 0 to 31976
# Data columns (total 75 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   phrase              19409 non-null  object
#  1   meaning             14552 non-null  object
#  2   dictionary          19409 non-null  object
#  3   англ                19409 non-null  bool
#  4   араб                19409 non-null  bool
#  5   библ                19409 non-null  bool
#  6   бран                19409 non-null  bool
#  7   воен                19409 non-null  bool
#  8   восторж             19409 non-null  bool
#  9   вульг               19409 non-null  bool
#  10  высок               19409 non-null  bool
#  11  греч                19409 non-null  bool
#  12  греч миф            19409 non-null  bool
#  13  груб                19409 non-null  bool
#  14  грубо-прост         19409 non-null  bool
#  15  детск               19409 non-null  bool
#  16  доревол             19409 non-null  bool
#  17  др-греч             19409 non-null  bool
#  18  еванг               19409 non-null  bool
#  19  жарг                19409 non-null  bool
#  20  иpoн                19409 non-null  bool
#  21  инф                 19409 non-null  bool
#  22  ист                 19409 non-null  bool
#  23  ит                  19409 non-null  bool
#  24  канц                19409 non-null  bool
#  25  книжн               19409 non-null  bool
#  26  лат                 19409 non-null  bool
#  27  лит                 19409 non-null  bool
#  28  миф                 19409 non-null  bool
#  29  мор                 19409 non-null  bool
#  30  народно-поэт        19409 non-null  bool
#  31  нем                 19409 non-null  bool
#  32  неодобрит           19409 non-null  bool
#  33  нов                 19409 non-null  bool
#  34  обл                 19409 non-null  bool
#  35  одобр               19409 non-null  bool
#  36  офиц                19409 non-null  bool
#  37  охот                19409 non-null  bool
#  38  перен               19409 non-null  bool
#  39  погов               19409 non-null  bool
#  40  пориц               19409 non-null  bool
#  41  посл                19409 non-null  bool
#  42  поэт                19409 non-null  bool
#  43  предосуд            19409 non-null  bool
#  44  презрит             19409 non-null  bool
#  45  пренебр             19409 non-null  bool
#  46  прост               19409 non-null  bool
#  47  публиц              19409 non-null  bool
#  48  разг                19409 non-null  bool
#  49  рел                 19409 non-null  bool
#  50  ритор               19409 non-null  bool
#  51  спец                19409 non-null  bool
#  52  спорт               19409 non-null  bool
#  53  театр               19409 non-null  bool
#  54  торж                19409 non-null  bool
#  55  уничиж              19409 non-null  bool
#  56  устар               19409 non-null  bool
#  57  фам                 19409 non-null  bool
#  58  физ                 19409 non-null  bool
#  59  филос               19409 non-null  bool
#  60  фольк               19409 non-null  bool
#  61  фр                  19409 non-null  bool
#  62  церк                19409 non-null  bool
#  63  церк-слав           19409 non-null  bool
#  64  шахм                19409 non-null  bool
#  65  шутл                19409 non-null  bool
#  66  шутл-ирон           19409 non-null  bool
#  67  шутл-фамильярн      19409 non-null  bool
#  68  эвф                 19409 non-null  bool
#  69  экспрес             19409 non-null  bool
#  70  этикет ф            19409 non-null  bool
#  71  этногр              19409 non-null  bool
#  72  юр                  19409 non-null  bool
#  73  label_counts        19409 non-null  int64
#  74  label_combinations  19409 non-null  object
# dtypes: bool(70), int64(1), object(4)
# memory usage: 2.2+ MB

# %%
pd.crosstab(df['phrase'], df['dictionary']).sum()
# Out:
# dictionary
# Fedorov        7222
# Fedosov        4659
# Kveselevich    4716
# Myurrey         388
# Volkova        2424
# dtype: int64

# %%
# Количество помет в каждом из словарей
def autopct(pct): 
    return '%.2f' % pct + '%'


pd.crosstab(df['phrase'], df['dictionary']).sum().sort_values(ascending=False).plot(kind='pie',
                                                       rot=0,
                                                      title='Объем словарей',
                                                      ylabel='',
                                                      autopct=autopct)
# Out:
# <AxesSubplot:title={'center':'Объем словарей'}>

# %%
# количество каждой из помет
labels_count = {}
for col in abbrs:
    if len(df[df[col]==True]) > 500:
        labels_count[len(df[df[col]==True])] = col
        print(col, len(df[df[col]==True]))
# Out:
# иpoн 749
# книжн 672
# неодобрит 540
# прост 3613
# разг 4260
# устар 2401
# экспрес 3022

# %%
#plt.figure(figsize=(10, 7))

labels_count_keys = sorted(list(labels_count.keys()), reverse=True)
labels_count_values = [labels_count[k] for k in labels_count_keys]

plt.bar(labels_count_values, labels_count_keys)
plt.title('Топ помет по частоте (>500)')
plt.show()

# %%
pd.crosstab(df['dictionary'], df['label_combinations']).sum()[1:].nlargest(7, keep='all').plot(kind='bar',
                                                                                            rot=10,
                                                                                            figsize=(12, 7),
                                                                                             width=0.8)
plt.show()

plt.bar(labels_count_values, labels_count_keys, color='orange')
plt.show()

# %%
unique_label_counts = list(set(row_labels))
plt.bar(unique_label_counts, [row_labels.count(label_count) for label_count in unique_label_counts])
plt.xlabel('Количество помет у идиомы')
plt.ylabel('Количество идиом')
plt.title('Распределение по количеству помет у одной идиомы')
plt.show()

# %%
df[df['label_counts'] == 5]
# Out:
#                     phrase meaning   dictionary   англ   араб  библ   бран  \
# 26204  ['яко тать в нощи']     NaN  Kveselevich  False  False  True  False
#
#         воен  восторж  вульг  ...   шутл  шутл-ирон  шутл-фамильярн    эвф  \
# 26204  False    False  False  ...  False      False           False  False
#
#        экспрес  этикет ф  этногр     юр  label_counts  \
# 26204    False     False   False  False             5
#
#                                    label_combinations
# 26204  ('библ', 'иpoн', 'устар', 'церк', 'церк-слав')
#
# [1 rows x 75 columns]

# %%
dicts = df['dictionary'].unique()

# %%
by_dictionary = df.groupby('dictionary')
labels_percent = {}
for dictionary in dicts:
    dict_group = by_dictionary.get_group(dictionary)
    total = len(dict_group)
    with_labels = len(dict_group['label_counts'][dict_group['label_counts'] > 0])
    
    labels_percent[round(with_labels / total * 100, 3)] = dictionary
    
labels_percent_keys = sorted(list(labels_percent.keys()), reverse=True)
labels_percent_values = [labels_percent[k] for k in labels_percent_keys]

plt.bar(labels_percent_values, labels_percent_keys, color='orange')
plt.xlabel('Словари')
plt.ylabel('%')
plt.title('% идиом с пометами')

plt.show()

# %%
dicts_group = df.groupby('dictionary').apply(lambda x: sum(x['label_counts']) / len (x))
print('Среднее количество помет на одну идиому по словарям')
print(dicts_group)
# Out:
# Среднее количество помет на одну идиому по словарям
# dictionary
# Fedorov        1.595818
# Fedosov        0.143808
# Kveselevich    0.829304
# Myurrey        0.000000
# Volkova        0.955446
# dtype: float64
