# %%
import pandas as pd
import json

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

large = 22; med = 14; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (12, 7),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)

# %%
with open('all_idioms.json', 'r', encoding='UTF-8') as f:
    data = tuple(json.load(f))

abbrs = {'презрит', 'эвф', 'груб', 'шутл-ирон', 'инф', 'ит', 'вульг', 'грубо-прост', 'канц', 'фр', 'мор', 'бран', 'поэт', 'устар', 'неодобрит', 'высок', 'одобр', 'шутл-фамильярн', 'этногр', 'ритор', 'книжн', 'восторж', 'этикет ф', 'посл', 'прост', 'библ', 'жарг', 'обл', 'шахм', 'офиц', 'миф', 'погов', 'юр', 'лит', 'доревол', 'перен', 'нов', 'фольк', 'спец', 'предосуд', 'еванг', 'лат', 'публиц', 'торж', 'греч', 'греч миф', 'спорт', 'англ', 'араб', 'ист', 'воен', 'др-греч', 'уничиж', 'пренебр', 'нем', 'пориц', 'разг', 'фам', 'экспрес', 'физ', 'театр', 'народно-поэт', 'церк-слав', 'охот', 'детск', 'иpoн', 'церк', 'шутл', 'филос', 'рел'}
len(abbrs)
# Out:
# 70

# %%
abbrs = sorted(list(abbrs))

# %%
df = pd.DataFrame(columns=['phrase', 'meaning', 'dictionary'] + sorted(list(abbrs)))
for phrase_dict in data:
    semantics_set = phrase_dict['semantics']
    for meaning_dict in semantics_set:
        if 'abbr' in list(meaning_dict.keys()) and 'dictionary' in list(meaning_dict.keys()):
            df.loc[len(df)] = [phrase_dict['phrase'],
                               meaning_dict['meaning'],
                               meaning_dict['dictionary']] + [True if abbr in meaning_dict['abbr'] else False for abbr in abbrs]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-91d003dad647> in <module>
#       4     for meaning_dict in semantics_set:
#       5         if 'abbr' in list(meaning_dict.keys()) and 'dictionary' in list(meaning_dict.keys()):
# ----> 6             df.loc[len(df)] = [phrase_dict['phrase'],
#       7                                meaning_dict['meaning'],
#       8                                meaning_dict['dictionary']] + [True if abbr in meaning_dict['abbr'] else False for abbr in abbrs]
#
# C:\anaconda\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# C:\anaconda\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1624
#    1625             if missing:
# -> 1626                 self._setitem_with_indexer_missing(indexer, value)
#    1627                 return
#    1628
#
# C:\anaconda\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1860                 value = Series(value, index=self.obj.columns, name=indexer)
#    1861
# -> 1862             self.obj._mgr = self.obj.append(value)._mgr
#    1863             self.obj._maybe_update_cacher(clear=True)
#    1864
#
# C:\anaconda\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7720                 combined_columns = self.columns.astype(object).append(idx_diff)
#    7721             other = (
# -> 7722                 other.reindex(combined_columns, copy=False)
#    7723                 .to_frame()
#    7724                 .T.infer_objects()
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in infer_objects(self)
#    5760         # native numpy numeric types
#    5761         return self._constructor(
# -> 5762             self._mgr.convert(
#    5763                 datetime=True, numeric=False, timedelta=True, coerce=False, copy=True
#    5764             )
#
# C:\anaconda\lib\site-packages\pandas\core\internals\managers.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#     603         coerce: bool = False,
#     604     ) -> "BlockManager":
# --> 605         return self.apply(
#     606             "convert",
#     607             copy=copy,
#
# C:\anaconda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\anaconda\lib\site-packages\pandas\core\internals\blocks.py in convert(self, copy, datetime, numeric, timedelta, coerce)
#    2418
#    2419         if self.ndim == 2:
# -> 2420             blocks = self.split_and_operate(None, f, False)
#    2421         else:
#    2422             values = f(None, self.values.ravel(), None)
#
# C:\anaconda\lib\site-packages\pandas\core\internals\blocks.py in split_and_operate(self, mask, f, inplace)
#     455
#     456             # need a new block
# --> 457             if m.any():
#     458                 nv = f(m, v, i)
#     459             else:
#
# KeyboardInterrupt:

# %%
df.head(10)
# Out:
#                                        phrase  \
# 0            [а вот на тебе!, и вот на тебе!]
# 1                         [а был ли мальчик?]
# 2                         [а был ли мальчик?]
# 3                                     [а вот]
# 4                    [а вот и нет, вот и нет]
# 5  [а ларчик просто открывался (открывается)]
# 6                            [а не то, не то]
# 7                            [а не то, не то]
# 8                            [а не то, не то]
# 9                    [а поди ж ты, поди ж ты]
#
#                                              meaning dictionary   англ   араб  \
# 0         Выражение удивления, разочарования и т. п.    Fedorov  False  False
# 1  Было ли что-либо в действительности, на самом ...    Fedorov  False  False
# 2   выражение сомнения в том, что что-то произошл...    Fedosov  False  False
# 3                                Напротив, наоборот.    Fedorov  False  False
# 4  Не выходит, нельзя сделать то, что намечается,...    Fedorov  False  False
# 5          Дело ясно, не требует долгих размышлений.    Fedorov  False  False
# 6                         Иначе, в противном случае.    Fedorov  False  False
# 7                                      Либо, или же.    Fedorov  False  False
# 8                          в противном случае, иначе    Fedosov  False  False
# 9  Выражение изумления, восхищения, недоумения и ...    Fedorov  False  False
#
#     библ   бран   воен восторж  вульг  ... церк-слав   шахм   шутл шутл-ирон  \
# 0  False  False  False   False  False  ...     False  False  False     False
# 1  False  False  False   False  False  ...     False  False  False     False
# 2  False  False  False   False  False  ...     False  False  False     False
# 3  False  False  False   False  False  ...     False  False  False     False
# 4  False  False  False   False  False  ...     False  False  False     False
# 5  False  False  False   False  False  ...     False  False  False     False
# 6  False  False  False   False  False  ...     False  False  False     False
# 7  False  False  False   False  False  ...     False  False  False     False
# 8  False  False  False   False  False  ...     False  False  False     False
# 9  False  False  False   False  False  ...     False  False  False     False
#
#   шутл-фамильярн    эвф экспрес этикет ф этногр     юр
# 0          False  False    True    False  False  False
# 1          False  False    True    False  False  False
# 2          False  False   False    False  False  False
# 3          False  False   False    False  False  False
# 4          False  False    True    False  False  False
# 5          False  False   False    False  False  False
# 6          False  False   False    False  False  False
# 7          False  False   False    False  False  False
# 8          False  False   False    False  False  False
# 9          False  False    True    False  False  False
#
# [10 rows x 73 columns]

# %%
# распределение фраз по количеству помет
#create a column with a tuple of all idiom's labels
row_labels = []
label_combinations = []
for ind, row in df.loc[:, 'англ': 'юр'].iterrows():
    row_labels.append(len(row[row].index))
    label_combinations.append(tuple(row[row].index))

df['label_counts'] = row_labels
df['label_combinations'] = label_combinations

# %%
df.head(10)
# Out:
#                                        phrase  \
# 0            [а вот на тебе!, и вот на тебе!]
# 1                         [а был ли мальчик?]
# 2                         [а был ли мальчик?]
# 3                                     [а вот]
# 4                    [а вот и нет, вот и нет]
# 5  [а ларчик просто открывался (открывается)]
# 6                            [а не то, не то]
# 7                            [а не то, не то]
# 8                            [а не то, не то]
# 9                    [а поди ж ты, поди ж ты]
#
#                                              meaning dictionary   англ   араб  \
# 0         Выражение удивления, разочарования и т. п.    Fedorov  False  False
# 1  Было ли что-либо в действительности, на самом ...    Fedorov  False  False
# 2   выражение сомнения в том, что что-то произошл...    Fedosov  False  False
# 3                                Напротив, наоборот.    Fedorov  False  False
# 4  Не выходит, нельзя сделать то, что намечается,...    Fedorov  False  False
# 5          Дело ясно, не требует долгих размышлений.    Fedorov  False  False
# 6                         Иначе, в противном случае.    Fedorov  False  False
# 7                                      Либо, или же.    Fedorov  False  False
# 8                          в противном случае, иначе    Fedosov  False  False
# 9  Выражение изумления, восхищения, недоумения и ...    Fedorov  False  False
#
#     библ   бран   воен восторж  вульг  ...   шутл шутл-ирон шутл-фамильярн  \
# 0  False  False  False   False  False  ...  False     False          False
# 1  False  False  False   False  False  ...  False     False          False
# 2  False  False  False   False  False  ...  False     False          False
# 3  False  False  False   False  False  ...  False     False          False
# 4  False  False  False   False  False  ...  False     False          False
# 5  False  False  False   False  False  ...  False     False          False
# 6  False  False  False   False  False  ...  False     False          False
# 7  False  False  False   False  False  ...  False     False          False
# 8  False  False  False   False  False  ...  False     False          False
# 9  False  False  False   False  False  ...  False     False          False
#
#      эвф экспрес этикет ф этногр     юр label_counts label_combinations
# 0  False    True    False  False  False            2    (разг, экспрес)
# 1  False    True    False  False  False            2    (разг, экспрес)
# 2  False   False    False  False  False            0                 ()
# 3  False   False    False  False  False            1            (разг,)
# 4  False    True    False  False  False            2    (разг, экспрес)
# 5  False   False    False  False  False            1            (иpoн,)
# 6  False   False    False  False  False            1           (прост,)
# 7  False   False    False  False  False            1           (прост,)
# 8  False   False    False  False  False            0                 ()
# 9  False    True    False  False  False            2   (прост, экспрес)
#
# [10 rows x 75 columns]

# %%
df.to_csv('dataframe.csv', sep=',', encoding='utf-8')

# %%
df_default = pd.read_csv('dataframe.csv', sep=',')

# %%
del df_default['Unnamed: 0']

# %%
phrase_one = df_default['phrase'].unique()
df = df_default[df_default['phrase'].isin(phrase_one)]

# %%
len(df['phrase'].unique())
# Out:
# 20727

# %%
description = df.describe()
description
# Out:
#        label_counts
# count  32747.000000
# mean       0.000794
# std        0.030257
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        2.000000

# %%
df
# Out:
#                                                   phrase  \
# 0                   ['а вот на тебе!', 'и вот на тебе!']
# 1                                  ['а был ли мальчик?']
# 2                                  ['а был ли мальчик?']
# 3                                              ['а вот']
# 4                           ['а вот и нет', 'вот и нет']
# ...                                                  ...
# 32742  ['Хорошо привешенный или подвешенный языку кого']
# 32743                     ['Язык не повернётся сказать']
# 32744       ['Языком трепать (чесать, болтать, молоть)']
# 32745                                    ['Язык чесать']
# 32746                          ['Ясный сокол (соколик)']
#
#                                                  meaning dictionary   англ  \
# 0             Выражение удивления, разочарования и т. п.    Fedorov  False
# 1      Было ли что-либо в действительности, на самом ...    Fedorov  False
# 2       выражение сомнения в том, что что-то произошл...    Fedosov  False
# 3                                    Напротив, наоборот.    Fedorov  False
# 4      Не выходит, нельзя сделать то, что намечается,...    Fedorov  False
# ...                                                  ...        ...    ...
# 32742   о человеке, к-рый бойко, плавно, хорошо говорит.    Volkova  False
# 32743                             нет решимости сказать.    Volkova  False
# 32744  говорить (зря, без толку, для препровождения в...    Volkova  False
# 32745  говорить зря, без толку, для препровождения вр...    Volkova  False
# 32746  употребляется как символическое обозначение мо...    Volkova  False
#
#         араб   библ   бран   воен  восторж  вульг  ...   шутл  шутл-ирон  \
# 0      False  False  False  False    False  False  ...  False      False
# 1      False  False  False  False    False  False  ...  False      False
# 2      False  False  False  False    False  False  ...  False      False
# 3      False  False  False  False    False  False  ...  False      False
# 4      False  False  False  False    False  False  ...  False      False
# ...      ...    ...    ...    ...      ...    ...  ...    ...        ...
# 32742  False  False  False  False    False  False  ...  False      False
# 32743  False  False  False  False    False  False  ...  False      False
# 32744  False  False  False  False    False  False  ...  False      False
# 32745  False  False  False  False    False  False  ...  False      False
# 32746  False  False  False  False    False  False  ...  False      False
#
#        шутл-фамильярн    эвф  экспрес  этикет ф  этногр     юр  label_counts  \
# 0               False  False    False     False   False  False             0
# 1               False  False    False     False   False  False             0
# 2               False  False    False     False   False  False             0
# 3               False  False    False     False   False  False             0
# 4               False  False    False     False   False  False             0
# ...               ...    ...      ...       ...     ...    ...           ...
# 32742           False  False    False     False   False  False             0
# 32743           False  False    False     False   False  False             0
# 32744           False  False    False     False   False  False             0
# 32745           False  False    False     False   False  False             0
# 32746           False  False    False     False   False  False             0
#
#        label_combinations
# 0                      ()
# 1                      ()
# 2                      ()
# 3                      ()
# 4                      ()
# ...                   ...
# 32742                  ()
# 32743                  ()
# 32744                  ()
# 32745                  ()
# 32746                  ()
#
# [32747 rows x 75 columns]

# %%
pd.crosstab(df['phrase'], df['dictionary']).sum()
# Out:
# dictionary
# Fedorov        11697
# Fedosov         6947
# Kveselevich     8337
# Myurrey          957
# Volkova         4809
# dtype: int64

# %%
# Количество помет в каждом из словарей
def autopct(pct): 
    return '%.2f' % pct + '%'


pd.crosstab(df['phrase'], df['dictionary']).sum().sort_values(ascending=False).plot(kind='pie',
                                                       rot=0,
                                                      title='Объем словарей',
                                                      ylabel='',
                                                      autopct=autopct)
# Out:
# <AxesSubplot:title={'center':'Объем словарей'}>

# %%
# количество каждой из помет
labels_count = {}
for col in abbrs:
    if len(df[df[col]==True]) > 500:
        labels_count[len(df[df[col]==True])] = col
        print(col, len(df[df[col]==True]))

# %%
#plt.figure(figsize=(10, 7))

labels_count_keys = sorted(list(labels_count.keys()), reverse=True)
labels_count_values = [labels_count[k] for k in labels_count_keys]

plt.bar(labels_count_values, labels_count_keys)
plt.title('Топ помет по частоте (>500)')
plt.show()

# %%
pd.crosstab(df['dictionary'], df['label_combinations']).sum()[1:].nlargest(7, keep='all').plot(kind='bar',
                                                                                            rot=10,
                                                                                            figsize=(12, 7),
                                                                                             width=0.8)
plt.show()

plt.bar(labels_count_values, labels_count_keys, color='orange')
plt.show()

# %%
unique_label_counts = list(set(row_labels))
plt.bar(unique_label_counts, [row_labels.count(label_count) for label_count in unique_label_counts])
plt.xlabel('Количество помет у идиомы')
plt.ylabel('Количество идиом')
plt.title('Распределение по количеству помет у одной идиомы')
plt.show()

# %%
df[df['label_counts'] == 5]

# %%
dicts = df['dictionary'].unique()

# %%
by_dictionary = df.groupby('dictionary')
labels_percent = {}
for dictionary in dicts:
    dict_group = by_dictionary.get_group(dictionary)
    total = len(dict_group)
    with_labels = len(dict_group['label_counts'][dict_group['label_counts'] > 0])
    
    labels_percent[round(with_labels / total * 100, 3)] = dictionary
    
labels_percent_keys = sorted(list(labels_percent.keys()), reverse=True)
labels_percent_values = [labels_percent[k] for k in labels_percent_keys]

plt.bar(labels_percent_values, labels_percent_keys, color='orange')
plt.xlabel('Словари')
plt.ylabel('%')
plt.title('% идиом с пометами')

plt.show()

# %%
dicts_group = df.groupby('dictionary').apply(lambda x: sum(x['label_counts']) / len (x))
print('Среднее количество помет на одну идиому по словарям')
print(dicts_group)
